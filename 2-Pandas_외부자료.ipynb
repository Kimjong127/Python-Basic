# %% [markdown]
# # Pandas 외부 파일 다루기
#
# 1. 텍스트 파일
# 1. 엑셀파일

# %% [markdown]
# 파일 `pandas_외부자료_data.zip` :
#
#     - '주요발생국가주간동향(4월2째주).csv'
#     - 'kto_201901.xlsx'
#     - 'nba.csv'
#     - '행정구역_읍면동_별_5세별_주민등록인구_2011년__20220622170418.xlsx'

# %%
#-*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1. 텍스트 파일
#
#  - csv, tsv, txt, json 등의 텍스트 형식

# %% [markdown]
# ## `read_csv()`
#
# [pandas.read_csv()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv)
#
#
#
# 주요 파라미터:
#
#  - `engine=` 옵션: 'c','python'. 파서 엔진으로 C엔진이 빠르다. python 엔진은 기능이 더 완전하다.
#  - `parse_date=`: boolean or list of ints or names or list of lists or dict, default False
#      - True면 index 파싱. 리스트를 묶어 하나로 파싱한다.

# %%
df = pd.read_csv('data/주요발생국가주간동향(4월2째주).csv')
df.head()
# Out:
#      국가   4월06일   4월07일   4월08일   4월09일   4월10일   4월11일   4월12일
# 0    미국  335524  364723  387547  424945  461437  495535  524903
# 1   스페인  130709  135032  140510  146690  152446  157022  161852
# 2  이탈리아  128948  132547  135586  139422  143626  147577  152271
# 3    독일  100024  102453  107591  112113  118181  122171  124908
# 4   프랑스   70478   74390   78167   82048   86334   90276   93790

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가      10 non-null     object
#  1   4월06일   10 non-null     int64
#  2   4월07일   10 non-null     int64
#  3   4월08일   10 non-null     int64
#  4   4월09일   10 non-null     int64
#  5   4월10일   10 non-null     int64
#  6   4월11일   10 non-null     int64
#  7   4월12일   10 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 768.0+ bytes

# %%
# 국가를 index
df = pd.read_csv('data/주요발생국가주간동향(4월2째주).csv', index_col=0)
df.head()
# Out:
#        4월06일   4월07일   4월08일   4월09일   4월10일   4월11일   4월12일
# 국가
# 미국    335524  364723  387547  424945  461437  495535  524903
# 스페인   130709  135032  140510  146690  152446  157022  161852
# 이탈리아  128948  132547  135586  139422  143626  147577  152271
# 독일    100024  102453  107591  112113  118181  122171  124908
# 프랑스    70478   74390   78167   82048   86334   90276   93790

# %%
pd.read

# %%
df.index

# %%
df.values

# %% [markdown]
# ### nba.csv

# %%
# - Data_Analysis_with_Pandas_Python 의 샘플
nba = pd.read_csv('https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/master/nba.csv')

# %%
#nba = pd.read_csv('data/nba.csv')
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# 나이와 몸무게를 출력

# %%
nba[['Age', 'Weight']].plot()
# Out:
# <AxesSubplot: >

# %%
nba.tail()

# %% [markdown]
# 전체 크기, 컬럼 이름,

# %%
nba.index

# %%
nba.shape

# %%
nba.columns

# %%
nba.axes

# %%
nba.info()

# %%
nba.dtypes

# %%
type(nba.values)

# %%
nba.values

# %% [markdown]
# 보유한 데이터의 형식별 숫자

# %%
# 0.25 Deprecated
# counts of data types: nba.get_dtype_counts()

# %% [markdown]
# # ex) Index 조회

# %%
nba.index

# %%
nba.loc[300]

# %%
nba.iloc[0]

# %% [markdown]
# #### ex) Index 와 column 동시 조회

# %%
nba.loc[200][['Age','Weight']]

# %% [markdown]
# #### ex) 조건 조회
#
# - info
# - describe
# - shape, ndim......
#
# 조건
#  - Age > 26
#  - Team == Utah Jazz & Salary > 900000

# %%
nba[(nba.Team == "Utah Jazz") & (nba.Salary > 900000)]
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 442   Trevor Booker  Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445      Dante Exum  Utah Jazz    11.0       PG  20.0    6-6   190.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 447     Rudy Gobert  Utah Jazz    27.0        C  23.0    7-1   245.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#           College      Salary
# 442       Clemson   4775000.0
# 443      Michigan   2658240.0
# 444      Colorado   9463484.0
# 445           NaN   3777720.0
# 446  Georgia Tech  12000000.0
# 447           NaN   1175880.0
# 448        Butler  15409570.0
# 449          Duke   1348440.0
# 450           NaN   2050000.0
# 451        Dayton    981348.0
# 452      Kentucky   2239800.0
# 453        Butler   2433333.0
# 455           NaN   2900000.0
# 456        Kansas    947276.0

# %%
nba[ (nba['Age'] > 30) & (nba['Weight'] > 100)]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31      Lou Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34     Jose Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43     Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..               ...                     ...     ...      ...   ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413    Nick Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415       Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
#      Weight           College      Salary
# 19    200.0      Georgia Tech   6300000.0
# 31    220.0              UNLV   1635476.0
# 33    240.0          Syracuse  22875000.0
# 34    200.0               NaN   7402812.0
# 43    195.0               NaN    947276.0
# ..      ...               ...         ...
# 406   212.0          Kentucky    947276.0
# 413   255.0            Kansas   3750000.0
# 415   213.0         Villanova   3135000.0
# 420   250.0          Kentucky    222888.0
# 434   265.0  Central Michigan   5016000.0
#
# [91 rows x 9 columns]

# %%
nba[ (nba['Age'] > 30) & (nba['Weight'] > 100)].plot()

# %% [markdown]
# ### 'UTF-8" encoding 에러
#
# ![스크린샷 2022-10-11 오후 5.04.31.png](attachment:a330a0d0-28f6-4c8a-a01b-0392b15719d0.png)
#
# encoding 을 unicode_escape 로 지정해 사용 가능하다.

# %%
# example
pd.read_csv('https://github.com/myeonghak/Recsys_MF_example/raw/master/ecommerce_data.csv', encoding='iso8859') # 'unicode_escape'
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### ex) 다음 링ㅋ의 과정을 위 nba 자료로 수행해 보자.
#
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html

# %% [markdown]
# # 2. Excel 파일
#
# 외부 데이터 파일 xls, xlsx 사용
#
#  - pandas 사용
#  - openpyxl 설치
#  - xlrd 설치

# %% [markdown]
# ####  openpyxl 과 xlrd
#
# openpyxl 은 Excel 2010 xlsx/xlsm/xltx/xltm 파일을 읽고/쓰기가 가능하다.
#
#  - https://pypi.org/project/openpyxl/
#
# ```Shell
# pip install -U openpyxl xlrd
#
# conda install -c anaconda openpyxl  xlrd
# ```

# %%
! pip install openpyxl xlrd
# Out:
# Requirement already satisfied: openpyxl in c:\users\sbauser\.venv\second_day\lib\site-packages (3.0.10)
# Requirement already satisfied: xlrd in c:\users\sbauser\.venv\second_day\lib\site-packages (2.0.1)
# Requirement already satisfied: et-xmlfile in c:\users\sbauser\.venv\second_day\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# ## `read_excel()`
#
# [pandas.read_excel()](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)
#
#
# 주요 파라미터:
#
#  - `sheet_name=` : 워크시트 이름
#  - `engine=`:  “xlrd”, “openpyxl”, “odf”, “pyxlsb"
#  - `parse_date=`: boolean or list of ints or names or list of lists or dict, default False
#      - True면 index 파싱. 리스트를 묶어 하나로 파싱한다.

# %% [markdown]
# ### xls 파일

# %%
seouppop = pd.read_excel('data/seoul_pop_22Q4Report.xls')
seouppop.head(3)
# Out:
#          기간 자치구   동   구분        계    0~4세    5~9세  10~14세  15~19세  20~24세  \
# 0  2022.1/4  합계  합계    계  9732617  243540  339987  371807  393705  634470
# 1  2022.1/4  합계  합계  한국인  9506778  239136  334035  367447  389156  602051
# 2  2022.1/4  합계  합계  외국인   225839    4404    5952    4360    4549   32419
#
#    ...  55~59세  60~64세  65~69세  70~74세  75~79세  80~84세 85~89세 90~94세 95~99세  \
# 0  ...  728425  737353  574423  401395  303760  206146  98787  34449   8282
# 1  ...  705262  723735  568754  399200  303035  205696  98529  34348   8234
# 2  ...   23163   13618    5669    2195     725     450    258    101     48
#
#   100세 이상+
# 0     1738
# 1     1711
# 2       27
#
# [3 rows x 26 columns]

# %% [markdown]
# ### xlsx 파일

# %%
foreign_201901 = pd.read_excel('data/kto_201901.xlsx', 
                          header=1,
                          usecols='A:G',
                          skipfooter=4)

foreign_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계
# 0  아시아주  765082  10837  1423  14087  125521  916950
# 1    일본  198805   2233   127    785    4576  206526
# 2    대만   86393     74    22    180    1285   87954
# 3    홍콩   34653     59     2     90    1092   35896
# 4   마카오    2506      2     0     17      45    2570

# %%
foreign_201901 = pd.read_excel('data/kto_201901.xlsx')

foreign_201901.head()
# Out:
#   2019년 01월 외래객 입국-목적별/국적별 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       국적         관광         상용         공용      유학/연수
# 1                     아시아주     765082      10837       1423      14087
# 2                       일본     198805       2233        127        785
# 3                       대만      86393         74         22        180
# 4                       홍콩      34653         59          2         90
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         기타          계       전년동기     성장률(%)     구성비(%)
# 1     125521     916950     775023       18.3         83
# 2       4576     206526     167083       23.6       18.7
# 3       1285      87954      75820         16          8
# 4       1092      35896      34671        3.5        3.2

# %% [markdown]
# ## 경고 / 에러

# %% [markdown]
# ### no default style
#
# ![image.png](attachment:5692ed49-e78b-4362-ba25-788bf7fa6b44.png)

# %%
import pandas as pd

# %%
df = pd.read_excel('data/행정구역_읍면동_별_5세별_주민등록인구_2011년__20220623170348.xlsx', header=1)
df
# Out:
# C:\Users\SBAUser\.venv\Second_day\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     행정구역(동읍면)별(1) 행정구역(동읍면)별(2)         항목         계   0 - 4세   5 - 9세  \
# 0              전국            소계   총인구수 (명)  51638809  1530469  2229881
# 1             NaN           NaN  남자인구수 (명)  25746684   785425  1142373
# 2             NaN           NaN  여자인구수 (명)  25892125   745044  1087508
# 3           서울특별시            소계   총인구수 (명)   9509458   244538   339145
# 4             NaN           NaN  남자인구수 (명)   4618040   126059   173705
# ..            ...           ...        ...       ...      ...      ...
# 838           NaN           NaN  남자인구수 (명)    246494     8983    13473
# 839           NaN           NaN  여자인구수 (명)    246602     8572    12730
# 840           NaN          서귀포시   총인구수 (명)    183663     5491     8738
# 841           NaN           NaN  남자인구수 (명)     92683     2868     4458
# 842           NaN           NaN  여자인구수 (명)     90980     2623     4280
#
#      10 - 14세  15 - 19세  20 - 24세  25 - 29세  ...  55 - 59세  60 - 64세  \
# 0     2364196   2345120   3121322   3534601  ...   4108389   4136749
# 1     1215920   1215429   1624175   1867507  ...   2087512   2046089
# 2     1148276   1129691   1497147   1667094  ...   2020877   2090660
# 3      367879    388257    603077    819200  ...    705302    722662
# 4      188872    198819    285890    398640  ...    348512    343867
# ..        ...       ...       ...       ...  ...       ...       ...
# 838     13978     13599     16057     16699  ...     19742     17268
# 839     13010     12215     14293     15207  ...     18490     17216
# 840      9363      8204      9306      9361  ...     15487     15169
# 841      4840      4393      5031      5032  ...      8244      7697
# 842      4523      3811      4275      4329  ...      7243      7472
#
#      65 - 69세  70 - 74세  75 - 79세  80 - 84세  85 - 89세  90 - 94세  95 - 99세  \
# 0     3027963   2109712   1605372   1201825    633656    217247     47297
# 1     1462656    986553    696848    457975    196253     49809      9042
# 2     1565307   1123159    908524    743850    437403    167438     38255
# 3      563260    396569    299231    199138     95871     33815      7920
# 4      263247    182384    134124     83319     33205      8844      1793
# ..        ...       ...       ...       ...       ...       ...       ...
# 838     11695      7898      5890      3870      1724       406        51
# 839     12320      9038      7544      6414      4388      1844       594
# 840     11209      8525      6888      5516      3318      1057       261
# 841      5462      4076      3049      2057       972       174        31
# 842      5747      4449      3839      3459      2346       883       230
#
#      100+
# 0    7961
# 1    1372
# 2    6589
# 3    1643
# 4     381
# ..    ...
# 838     6
# 839   115
# 840    74
# 841     4
# 842    70
#
# [843 rows x 25 columns]

# %%
import openpyxl as opyxl

load_wb = opyxl.load_workbook('../data/행정구역/행정구역_읍면동_별_5세별_주민등록인구_2011년__20220622170418.xlsx',
                              data_only=True)
population = load_wb['데이터']

# %% [markdown]
# 경고는 openpyxl 을 기본으로 사용하라는 의미로 아래 같이 엔진을 지정하면 된다.

# %%
df = pd.read_excel('../data/행정구역/행정구역_읍면동_별_5세별_주민등록인구_2011년__20220622170418.xlsx', 
                   header=1,
                   engine="openpyxl")

# %% [markdown]
# # 3. 화면 옵션

# %%
pd.set_option('display.float_format', '{:.3}'.format)  # exponent 표현
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ## Tqdm Pandas Integrations
#
# - https://github.com/tqdm/tqdm/#pandas-integration

# %% [markdown]
# ### IPython/Jupyter Integration
#
#  - https://github.com/tqdm/tqdm/#table-of-contents
#
# IPython/Jupyter is supported via the tqdm.notebook submodule:

# %%
from tqdm.notebook import trange, tqdm
from time import sleep

for i in trange(3, desc='1st loop'):
    for j in tqdm(range(100), desc='2nd loop'):
        sleep(0.01)

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

df = pd.DataFrame(np.random.randint(0, 100, (100000, 6)))

# Register `pandas.progress_apply` and `pandas.Series.map_apply` with `tqdm`
# (can use `tqdm.gui.tqdm`, `tqdm.notebook.tqdm`, optional kwargs, etc.)
tqdm.pandas(desc="my bar!")

# Now you can use `progress_apply` instead of `apply`
# and `progress_map` instead of `map`
df.progress_apply(lambda x: x**2)
# can also groupby:
# df.groupby(0).progress_apply(lambda x: x**2)

# %% [markdown]
# # 참고
#  - 도서 *Data_Analysis_with_Pandas_Python* , Pandas 로 데이터를 다루는 예
#  - https://bitbucket.org/hrojas/learn-pandas
