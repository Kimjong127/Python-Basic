# %% [markdown]
# # 판다스 연습 튜토리얼 20-43 / 100

# %% [markdown]
# 목차 및 구성 출처 : https://github.com/guipsamora/pandas_exercises

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 02 Filtering & Sorting

# %% [markdown]
# ## 식당데이터
#  - https://github.com/justmarkham/DAT8/blob/master/data/chipotle.tsv
#  - data url: 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'

# %% [markdown]
# ### Question 20
#
# **식당 데이터를 로드하자.**

# %%
DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'
df = pd.read_csv(DataUrl)

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# 식당 데이터에서 quantity 칼럽의 중복하지 않는 값을 출력해 보자

# %%
df['quantity'].unique()
# Out:
# array([ 1,  2,  3,  4,  5, 15,  7,  8, 10], dtype=int64)

# %% [markdown]
# 식당 데이터에서 quantity 칼럼의 중복하지 않는 각 값의 개수를 출력해 보자

# %%
df['quantity'].value_counts()
# Out:
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %%
# Out:
# 1     4355
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %% [markdown]
# ### Question 21
#
# **quantity 컬럼 값이 5 보다 큰 값을 찾아서 결과를 5행만 출력하라**

# %%
Ans = df.loc[df['quantity'] >= 5].head()

# %%
Ans
# Out:
#       order_id  quantity                     item_name choice_description  \
# 2441       970         5                 Bottled Water                NaN
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
# 3599      1443         7                 Bottled Water                NaN
# 3887      1559         8                 Side of Chips                NaN
# 4152      1660        10                 Bottled Water                NaN
#
#      item_price
# 2441     $7.50
# 3598    $44.25
# 3599    $10.50
# 3887    $13.52
# 4152    $15.00

# %%
# 복합조건 /관계 식 : & | ^    -> ()로 묶어.

# %%
# 주문량이 5개 이상이고 item_name이 'Side fo Chips' 인 것.

# %%
df.loc[ (df['quantity'] >= 2) & (df['item_name'] == 'Side of Chips') ]
# Out:
#       order_id  quantity      item_name choice_description item_price
# 2944      1170         3  Side of Chips                NaN     $5.07
# 3887      1559         8  Side of Chips                NaN    $13.52

# %%
df.loc[ (df['quantity'] >= 2) & (df['item_name'] == 'Side of Chips') ]['order_id']
# Out:
# 2944    1170
# 3887    1559
# Name: order_id, dtype: int64

# %%
df.loc[ (df['quantity'] >= 2) & (df['item_name'] == 'Side of Chips'), 'order_id' ]
# Out:
# 2944    1170
# 3887    1559
# Name: order_id, dtype: int64

# %%
df[ (df['quantity'] >= 2) & (df['item_name'] == 'Side of Chips') ]['order_id' ]
# Out:
# 2944    1170
# 3887    1559
# Name: order_id, dtype: int64

# %%
# quantity 3개 ~ 5개 사이인 것.

df.loc[(df['quantity'] >= 3) & (df['quantity'] <= 5)]
# Out:
#       order_id  quantity                            item_name  \
# 409        178         3                         Chicken Bowl
# 445        193         3                                 Bowl
# 689        284         3                    Canned Soft Drink
# 818        338         3                        Bottled Water
# 850        350         3                    Canned Soft Drink
# 917        379         3                    Canned Soft Drink
# 1254       511         4                      Chicken Burrito
# 1255       511         3                        Steak Burrito
# 1257       511         4         Chips and Fresh Tomato Salsa
# 1425       577         4                        Bottled Water
# 1514       616         3                         Chicken Bowl
# 1559       633         3                    Canned Soft Drink
# 1880       759         4                        Bottled Water
# 2235       901         4                          Canned Soda
# 2441       970         5                        Bottled Water
# 2645      1051         3                  Chips and Guacamole
# 2823      1121         3                        Bottled Water
# 2936      1167         3                                Chips
# 2944      1170         3                        Side of Chips
# 2972      1182         3  Chips and Tomatillo-Red Chili Salsa
# 3089      1231         3                    Canned Soft Drink
# 3128      1247         3                    Canned Soft Drink
# 3270      1309         3  Chips and Tomatillo-Red Chili Salsa
# 3294      1321         3                        Bottled Water
# 3314      1328         3                        Bottled Water
# 3334      1336         3                           Steak Bowl
# 3480      1398         3                        Carnitas Bowl
# 3601      1443         3                       Veggie Burrito
# 3602      1443         4                      Chicken Burrito
# 3603      1443         3                        Steak Burrito
# 3634      1454         3                      Chicken Burrito
# 3636      1454         3                      Chicken Burrito
# 3973      1592         4                    Canned Soft Drink
# 4098      1642         3                    Canned Soft Drink
# 4137      1655         3                        Bottled Water
# 4186      1671         3                        Bottled Water
# 4489      1786         4                  Chips and Guacamole
# 4490      1786         4                    Canned Soft Drink
# 4491      1786         4                    Canned Soft Drink
#
#                                      choice_description item_price
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                         [Diet Coke]     $3.75
# 818                                                 NaN     $3.27
# 850                                            [Sprite]     $3.75
# 917                                          [Lemonade]     $3.75
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# 1255  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $27.75
# 1257                                                NaN    $11.80
# 1425                                                NaN     $6.00
# 1514  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $26.25
# 1559                                             [Coke]     $3.75
# 1880                                                NaN     $6.00
# 2235                                           [Sprite]     $4.36
# 2441                                                NaN     $7.50
# 2645                                                NaN    $13.35
# 2823                                                NaN     $3.27
# 2936                                                NaN     $6.45
# 2944                                                NaN     $5.07
# 2972                                                NaN     $7.17
# 3089                                        [Diet Coke]     $3.75
# 3128                                        [Diet Coke]     $3.75
# 3270                                                NaN     $7.17
# 3294                                                NaN     $4.50
# 3314                                                NaN     $4.50
# 3334  [Tomatillo Green Chili (Medium), [Rice, Black ...    $26.07
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# 3634                               [Fresh Tomato Salsa]    $26.25
# 3636                         [Fresh Tomato Salsa, Rice]    $26.25
# 3973                                             [Coke]     $5.00
# 4098                                        [Diet Coke]     $3.75
# 4137                                                NaN     $4.50
# 4186                                                NaN     $4.50
# 4489                                                NaN    $17.80
# 4490                                             [Coke]     $5.00
# 4491                                           [Sprite]     $5.00

# %%
# item이 'Side of Chips' 혹은 'Bottled Water'인 것.

df.loc[ (df['item_name'] == 'Side of Chips') | (df['item_name'] == 'bottled Water') ]
# Out:
#       order_id  quantity                            item_name  \
# 409        178         3                         Chicken Bowl
# 445        193         3                                 Bowl
# 689        284         3                    Canned Soft Drink
# 818        338         3                        Bottled Water
# 850        350         3                    Canned Soft Drink
# 917        379         3                    Canned Soft Drink
# 1254       511         4                      Chicken Burrito
# 1255       511         3                        Steak Burrito
# 1257       511         4         Chips and Fresh Tomato Salsa
# 1425       577         4                        Bottled Water
# 1514       616         3                         Chicken Bowl
# 1559       633         3                    Canned Soft Drink
# 1880       759         4                        Bottled Water
# 2235       901         4                          Canned Soda
# 2441       970         5                        Bottled Water
# 2645      1051         3                  Chips and Guacamole
# 2823      1121         3                        Bottled Water
# 2936      1167         3                                Chips
# 2944      1170         3                        Side of Chips
# 2972      1182         3  Chips and Tomatillo-Red Chili Salsa
# 3089      1231         3                    Canned Soft Drink
# 3128      1247         3                    Canned Soft Drink
# 3270      1309         3  Chips and Tomatillo-Red Chili Salsa
# 3294      1321         3                        Bottled Water
# 3314      1328         3                        Bottled Water
# 3334      1336         3                           Steak Bowl
# 3480      1398         3                        Carnitas Bowl
# 3601      1443         3                       Veggie Burrito
# 3602      1443         4                      Chicken Burrito
# 3603      1443         3                        Steak Burrito
# 3634      1454         3                      Chicken Burrito
# 3636      1454         3                      Chicken Burrito
# 3973      1592         4                    Canned Soft Drink
# 4098      1642         3                    Canned Soft Drink
# 4137      1655         3                        Bottled Water
# 4186      1671         3                        Bottled Water
# 4489      1786         4                  Chips and Guacamole
# 4490      1786         4                    Canned Soft Drink
# 4491      1786         4                    Canned Soft Drink
#
#                                      choice_description item_price
# 409   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                         [Diet Coke]     $3.75
# 818                                                 NaN     $3.27
# 850                                            [Sprite]     $3.75
# 917                                          [Lemonade]     $3.75
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# 1255  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $27.75
# 1257                                                NaN    $11.80
# 1425                                                NaN     $6.00
# 1514  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $26.25
# 1559                                             [Coke]     $3.75
# 1880                                                NaN     $6.00
# 2235                                           [Sprite]     $4.36
# 2441                                                NaN     $7.50
# 2645                                                NaN    $13.35
# 2823                                                NaN     $3.27
# 2936                                                NaN     $6.45
# 2944                                                NaN     $5.07
# 2972                                                NaN     $7.17
# 3089                                        [Diet Coke]     $3.75
# 3128                                        [Diet Coke]     $3.75
# 3270                                                NaN     $7.17
# 3294                                                NaN     $4.50
# 3314                                                NaN     $4.50
# 3334  [Tomatillo Green Chili (Medium), [Rice, Black ...    $26.07
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# 3634                               [Fresh Tomato Salsa]    $26.25
# 3636                         [Fresh Tomato Salsa, Rice]    $26.25
# 3973                                             [Coke]     $5.00
# 4098                                        [Diet Coke]     $3.75
# 4137                                                NaN     $4.50
# 4186                                                NaN     $4.50
# 4489                                                NaN    $17.80
# 4490                                             [Coke]     $5.00
# 4491                                           [Sprite]     $5.00

# %%
# item이 'Side of Chips' 혹은 'Bottled Water'인 것.

t = df.loc[ (df['item_name'] == 'Side of Chips') | (df['item_name'] == 'Bottled Water') ]
t.shape
# Out:
# (263, 5)

# %% [markdown]
# ### Question 22
# **quantity컬럼 값이 3인 데이터를 추출하여 index를 0부터 정렬하고 첫 5행을 출력하라**

# %%
Ans = df.loc[df['quantity']==3].head()

# %%
Ans
# Out:
#      order_id  quantity          item_name  \
# 409       178         3       Chicken Bowl
# 445       193         3               Bowl
# 689       284         3  Canned Soft Drink
# 818       338         3      Bottled Water
# 850       350         3  Canned Soft Drink
#
#                                     choice_description item_price
# 409  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 689                                        [Diet Coke]     $3.75
# 818                                                NaN     $3.27
# 850                                           [Sprite]     $3.75

# %% [markdown]
# 결과에서 index 를 0 부터 사용하도록 하자. 단 기존 인덱스 값은 제거한다.

# %%
Ans.reset_index() # index값을 초기화
# Out:
#    index  order_id  quantity          item_name  \
# 0    409       178         3       Chicken Bowl
# 1    445       193         3               Bowl
# 2    689       284         3  Canned Soft Drink
# 3    818       338         3      Bottled Water
# 4    850       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %%
Ans.reset_index(drop=True)
# Out:
#    order_id  quantity          item_name  \
# 0       178         3       Chicken Bowl
# 1       193         3               Bowl
# 2       284         3  Canned Soft Drink
# 3       338         3      Bottled Water
# 4       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %% [markdown]
# #### 문자열...```Series.str``` 속성

# %%
df['item_name'].str.replace('I', '-I')
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                       -Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df.loc[ (df['item_name'].str.contains('I')) & (df['quantity'] >= 1 )]
# Out:
#       order_id  quantity item_name choice_description item_price
# 1            1         1      Izze       [Clementine]     $3.39
# 24          12         1      Izze       [Grapefruit]     $3.39
# 47          21         1      Izze       [Blackberry]     $3.39
# 66          30         1      Izze       [Blackberry]     $3.39
# 359        155         1      Izze       [Blackberry]     $3.39
# 360        155         1      Izze       [Grapefruit]     $3.39
# 430        186         1      Izze       [Grapefruit]     $3.39
# 579        237         1      Izze       [Clementine]     $3.39
# 580        237         1      Izze       [Grapefruit]     $3.39
# 1059       436         1      Izze       [Clementine]     $3.39
# 1213       495         1      Izze       [Clementine]     $3.39
# 1611       651         1      Izze       [Blackberry]     $3.39
# 1612       651         1      Izze       [Blackberry]     $3.39
# 1680       680         1      Izze       [Clementine]     $3.39
# 2088       842         1      Izze       [Clementine]     $3.39
# 2619      1040         1      Izze       [Clementine]     $3.39
# 2634      1046         1      Izze       [Clementine]     $3.39
# 2758      1095         1      Izze       [Blackberry]     $3.39
# 2891      1149         1      Izze       [Blackberry]     $3.39
# 3669      1468         1      Izze       [Blackberry]     $3.39

# %% [markdown]
# ### Question 23
#
# **quantity , item_price 두개의 컬럼을 새로운 데이터 프레임으로 저장한다**

# %%
Ans = df[['quantity', 'item_price']]

# %%
Ans
# Out:
#       quantity item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617         1    $11.75
# 4618         1    $11.75
# 4619         1    $11.25
# 4620         1     $8.75
# 4621         1     $8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Question 24
#
# **item_price 컬럼의 중복하지 않은 값만 출력하자**

# %%
df['item_price'].unique()
# Out:
# array(['$2.39 ', '$3.39 ', '$16.98 ', '$10.98 ', '$1.69 ', '$11.75 ',
#        '$9.25 ', '$4.45 ', '$8.75 ', '$11.25 ', '$8.49 ', '$2.18 ',
#        '$8.99 ', '$1.09 ', '$2.95 ', '$2.15 ', '$3.99 ', '$22.50 ',
#        '$11.48 ', '$17.98 ', '$17.50 ', '$4.30 ', '$5.90 ', '$1.25 ',
#        '$23.78 ', '$6.49 ', '$11.08 ', '$1.50 ', '$22.16 ', '$32.94 ',
#        '$22.20 ', '$10.58 ', '$2.50 ', '$23.50 ', '$7.40 ', '$18.50 ',
#        '$3.00 ', '$6.78 ', '$11.89 ', '$9.39 ', '$4.00 ', '$3.75 ',
#        '$8.69 ', '$2.29 ', '$8.90 ', '$3.27 ', '$3.89 ', '$8.19 ',
#        '$35.00 ', '$27.75 ', '$11.80 ', '$6.00 ', '$26.25 ', '$21.96 ',
#        '$4.36 ', '$7.50 ', '$4.78 ', '$13.35 ', '$6.45 ', '$5.07 ',
#        '$22.96 ', '$7.17 ', '$7.98 ', '$4.50 ', '$26.07 ', '$12.98 ',
#        '$35.25 ', '$44.25 ', '$10.50 ', '$33.75 ', '$16.38 ', '$13.52 ',
#        '$5.00 ', '$15.00 ', '$8.50 ', '$17.80 ', '$1.99 ', '$11.49 '],
#       dtype=object)

# %% [markdown]
# **item_price 컬럼의 달러표시 문자를 제거하고 float 타입으로 저장하여 new_price 컬럼에 저장하라**

# %%
df['item_price'].str.split('$')
# Out:
# 0        [, 2.39 ]
# 1        [, 3.39 ]
# 2        [, 3.39 ]
# 3        [, 2.39 ]
# 4       [, 16.98 ]
#            ...
# 4617    [, 11.75 ]
# 4618    [, 11.75 ]
# 4619    [, 11.25 ]
# 4620     [, 8.75 ]
# 4621     [, 8.75 ]
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'].str.replace('$', '')
# Out:
# C:\Users\SBAUser\AppData\Local\Temp\ipykernel_13472\2975590340.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'].str.replace('$', '')
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['item_price'].str[1:]
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df['new_price'] = df['item_price'].str[1:].astype(np.float16)
df['new_price'].head()
# Out:
# 0     2.390625
# 1     3.390625
# 2     3.390625
# 3     2.390625
# 4    16.984375
# Name: new_price, dtype: float16

# %%
Ans
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: new_price, dtype: float64

# %% [markdown]
# ### Question 25
#
# **new_price 컬럼이 5이하의 값을 가지는 데이터프레임을 추출하고, 행의 갯수를 구하여라**
#  - shape 이용

# %%
df.loc[df.new_price <=5].shape
# Out:
# (1652, 6)

# %%
Ans = df.loc[df.new_price <=5]
Ans.shape[0]
# Out:
# 1652

# %%
len(Ans)
# Out:
# 1652

# %% [markdown]
# 파이썬 len 을 사용해서 new_price 컬럼이 5이하의 값의 개수를 출력하지

# %%
print(len(df.loc[df.new_price <= 5]))
# Out:
# 1652

# %% [markdown]
# ### Question 26
# **item_name명이 Chicken Salad Bowl 인 데이터 프레임을 추출하자**

# %%
Ans = df.loc[df.item_name == 'Chicken Salad Bowl']
Ans
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4561      1813         2  Chicken Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50       22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50       22.50
# 256   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75        8.75
# 315             [Fresh Tomato Salsa, Fajita Vegetables]    $17.50       17.50
# ...                                                 ...        ...        ...
# 4561  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $17.50       17.50
# 4580  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...    $11.25       11.25
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [110 rows x 6 columns]

# %% [markdown]
# 결과에서 **index 값을 초기화 해서 인덱스를 0부터 시작하도록 한다. 그리고  Ans 에 저장한다.**

# %%
Ans = Ans.reset_index(drop=True)
Ans
# Out:
#      order_id  quantity           item_name  \
# 0          20         1  Chicken Salad Bowl
# 1          60         2  Chicken Salad Bowl
# 2          94         2  Chicken Salad Bowl
# 3         111         1  Chicken Salad Bowl
# 4         137         2  Chicken Salad Bowl
# ..        ...       ...                 ...
# 105      1813         2  Chicken Salad Bowl
# 106      1822         1  Chicken Salad Bowl
# 107      1834         1  Chicken Salad Bowl
# 108      1834         1  Chicken Salad Bowl
# 109      1834         1  Chicken Salad Bowl
#
#                                     choice_description item_price  new_price
# 0    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 1    [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50       22.50
# 2    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $22.50       22.50
# 3    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75        8.75
# 4              [Fresh Tomato Salsa, Fajita Vegetables]    $17.50       17.50
# ..                                                 ...        ...        ...
# 105  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $17.50       17.50
# 106  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...    $11.25       11.25
# 107  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 108  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 109  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [110 rows x 6 columns]

# %% [markdown]
# item_name명이 `Steak Burrito` 인 데이터 프레임을 추출해서 Burito에 저장한다.

# %%
Burito = df.loc[df.item_name == 'Steak Burrito']
Burito
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description item_price  new_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75   11.750000
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25    9.250000
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...     $8.99    8.992188
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.75   11.750000
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...     $8.99    8.992188
# ...                                                 ...        ...        ...
# 4546  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]     $9.25    9.250000
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...    $11.75   11.750000
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75   11.750000
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75   11.750000
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75   11.750000
#
# [368 rows x 6 columns]

# %% [markdown]
# Burito 의 index 값을 초기화 해서 인덱스를 0부터 시작하는데 inplace 를 사용해서 Burito 객체에 바로 적용하게 하고 앞에서 10개를 출력한다

# %%
Burito = Burito.reset_index(drop=True)
Burito.head(10)
# Out:
#    order_id  quantity      item_name  \
# 0         4         1  Steak Burrito
# 1         5         1  Steak Burrito
# 2        16         1  Steak Burrito
# 3        20         1  Steak Burrito
# 4        21         1  Steak Burrito
# 5        22         1  Steak Burrito
# 6        23         1  Steak Burrito
# 7        29         1  Steak Burrito
# 8        30         1  Steak Burrito
# 9        31         1  Steak Burrito
#
#                                   choice_description item_price  new_price
# 0  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75   11.750000
# 1  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25    9.250000
# 2  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...     $8.99    8.992188
# 3  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.75   11.750000
# 4  [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...     $8.99    8.992188
# 5  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.99    8.992188
# 6  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...     $8.99    8.992188
# 7  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99    8.992188
# 8  [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]     $8.99    8.992188
# 9  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...     $8.99    8.992188

# %% [markdown]
# ### Question 27
#
# **new_price값이 9 이하이고 item_name 값이 Chicken Salad Bowl 인 데이터 프레임을 추출하라**

# %%
# Out:
#      order_id  quantity           item_name  \
# 44         20         1  Chicken Salad Bowl
# 256       111         1  Chicken Salad Bowl
# 526       220         1  Chicken Salad Bowl
# 528       221         1  Chicken Salad Bowl
# 529       221         1  Chicken Salad Bowl
#
#                                     choice_description item_price  new_price
# 44   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 256  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $8.75        8.75
# 526  [Roasted Chili Corn Salsa, [Black Beans, Sour ...     $8.75        8.75
# 528  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75        8.75
# 529  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $8.75        8.75

# %% [markdown]
# Ans 의 인덱스를 0 부터 시작하도록 초기화 하고 inplace 방식으로 적용하자

# %% [markdown]
# ### Question 28
# **df의 new_price 컬럼 값에 따라 오름차순으로 정리하고 index를 초기화 하여라**

# %%
Ans.head(4)
# Out:
#    order_id  quantity      item_name choice_description item_price  new_price
# 0       471         1  Bottled Water                NaN     $1.09        1.09
# 1       338         1    Canned Soda        [Coca Cola]     $1.09        1.09
# 2      1575         1    Canned Soda       [Dr. Pepper]     $1.09        1.09
# 3        47         1    Canned Soda       [Dr. Pepper]     $1.09        1.09

# %% [markdown]
# ### Question 29
#
# **df의 item_name 컬럼의 값 중에서 `Chips` 포함하는 데이터를 출력하라**

# %%
Ans.head(5)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 6          3         1                          Side of Chips
# 10         5         1                    Chips and Guacamole
# 14         7         1                    Chips and Guacamole
#
#    choice_description item_price  new_price
# 0                 NaN     $2.39        2.39
# 3                 NaN     $2.39        2.39
# 6                 NaN     $1.69        1.69
# 10                NaN     $4.45        4.45
# 14                NaN     $4.45        4.45

# %% [markdown]
# **Chips 를 포함하지 않는 데이터만 출력하자**

# %%
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [3538 rows x 6 columns]

# %% [markdown]
# ### Question 30
#
# df 의 컬럼을 출력하자

# %%
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'new_price'],
#       dtype='object')

# %% [markdown]
# **df의 컬럼 순서에서 짝수 번째 칼럼만 출력하자**

# %%
Ans = df.iloc[:, ::2]

# %%
Ans.head(5)
# Out:
#    order_id                              item_name item_price
# 0         1           Chips and Fresh Tomato Salsa     $2.39
# 1         1                                   Izze     $3.39
# 2         1                       Nantucket Nectar     $3.39
# 3         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4         2                           Chicken Bowl    $16.98

# %% [markdown]
# df 에서 컬럼에서 역순으로 짝수번째 컬럼을 추출해 보자

# %%
df.iloc[:,::-2]
# Out:
#       new_price                                 choice_description  quantity
# 0      2.390625                                                NaN         1
# 1      3.390625                                       [Clementine]         1
# 2      3.390625                                            [Apple]         1
# 3      2.390625                                                NaN         1
# 4     16.984375  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...         2
# ...         ...                                                ...       ...
# 4617  11.750000  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...         1
# 4618  11.750000  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...         1
# 4619  11.250000  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
# 4620   8.750000  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...         1
# 4621   8.750000  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...         1
#
# [4622 rows x 3 columns]

# %% [markdown]
# df 에서 역순으로 짝수번째 행 만을 추출해 보자

# %%
# Out:
#       order_id  quantity                              item_name  \
# 4621      1834         1                     Chicken Salad Bowl
# 4619      1834         1                     Chicken Salad Bowl
# 4617      1833         1                          Steak Burrito
# 4615      1832         1                     Chicken Soft Tacos
# 4613      1831         1                                  Chips
# ...        ...       ...                                    ...
# 9            5         1                          Steak Burrito
# 7            4         1                          Steak Burrito
# 5            3         1                           Chicken Bowl
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 1            1         1                                   Izze
#
#                                      choice_description item_price  new_price
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75        8.75
# 4613                                                NaN     $2.15        2.15
# ...                                                 ...        ...        ...
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98       10.98
# 3                                                   NaN     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
#
# [2311 rows x 6 columns]

# %% [markdown]
# df 에서 역순으로 홀수번째 행 만을 추출해 보자

# %%
# Out:
#       order_id  quantity            item_name  \
# 4621      1834         1   Chicken Salad Bowl
# 4618      1833         1        Steak Burrito
# 4615      1832         1   Chicken Soft Tacos
# 4612      1831         1        Carnitas Bowl
# 4609      1829         1    Canned Soft Drink
# ...        ...       ...                  ...
# 13           7         1         Chicken Bowl
# 10           5         1  Chips and Guacamole
# 7            4         1        Steak Burrito
# 4            2         2         Chicken Bowl
# 1            1         1                 Izze
#
#                                      choice_description item_price  new_price
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75        8.75
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25        9.25
# 4609                                           [Sprite]     $1.25        1.25
# ...                                                 ...        ...        ...
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25       11.25
# 10                                                  NaN     $4.45        4.45
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 1                                          [Clementine]     $3.39        3.39
#
# [1541 rows x 6 columns]

# %% [markdown]
# ### Question 31
#
# **df의 new_price 컬럼 값에 따라 내림차순으로 정리하고 index를 초기화 하여라**
#  - sort_values

# %%
df['new_price']
# Out:
# 0        2.390625
# 1        3.390625
# 2        3.390625
# 3        2.390625
# 4       16.984375
#           ...
# 4617    11.750000
# 4618    11.750000
# 4619    11.250000
# 4620     8.750000
# 4621     8.750000
# Name: new_price, Length: 4622, dtype: float16

# %%
Ans = df.sort_values('new_price', ascending=False).reset_index(drop=True)

# %%
Ans.head(4)
# Out:
#    order_id  quantity                     item_name  \
# 0      1443        15  Chips and Fresh Tomato Salsa
# 1      1398         3                 Carnitas Bowl
# 2       511         4               Chicken Burrito
# 3      1443         4               Chicken Burrito
#
#                                   choice_description item_price  new_price
# 0                                                NaN    $44.25       44.25
# 1  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25       35.25
# 2  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00       35.00
# 3  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00       35.00

# %%
df.sort_values(['new_price','item_name'], ascending=True)
# Out:
#       order_id  quantity                     item_name  \
# 34          17         1                 Bottled Water
# 87          38         1                 Bottled Water
# 318        138         1                 Bottled Water
# 701        288         1                 Bottled Water
# 780        321         1                 Bottled Water
# ...        ...       ...                           ...
# 3601      1443         3                Veggie Burrito
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3480      1398         3                 Carnitas Bowl
# 3598      1443        15  Chips and Fresh Tomato Salsa
#
#                                      choice_description item_price  new_price
# 34                                                  NaN     $1.09    1.089844
# 87                                                  NaN     $1.09    1.089844
# 318                                                 NaN     $1.09    1.089844
# 701                                                 NaN     $1.09    1.089844
# 780                                                 NaN     $1.09    1.089844
# ...                                                 ...        ...        ...
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75   33.750000
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00   35.000000
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00   35.000000
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25   35.250000
# 3598                                                NaN    $44.25   44.250000
#
# [4622 rows x 6 columns]

# %% [markdown]
# ### Question 32
# **df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 인덱싱하라**

# %%
Ans
# Out:
#       order_id  quantity item_name  \
# 7            4         1      King
# 8            4         1      King
# 9            5         1      King
# 39          19         1      King
# 43          20         1      King
# ...        ...       ...       ...
# 4607      1829         1      King
# 4610      1830         1      King
# 4612      1831         1      King
# 4617      1833         1      King
# 4618      1833         1      King
#
#                                      choice_description item_price  new_price  \
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25        9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75       11.75
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.75       11.75
# ...                                                 ...        ...        ...
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...    $11.75       11.75
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25        9.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
#
#      choice_descripiton
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 39                  NaN
# 43                  NaN
# ...                 ...
# 4607                NaN
# 4610                NaN
# 4612                NaN
# 4617                NaN
# 4618                NaN
#
# [682 rows x 7 columns]

# %% [markdown]
# ### Question 33
#
# **df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 Ans 에 데이터 프레임 저장한 후에 item_name를 기준으로 중복 행이 있으면 제거한다**
#  - drop_duplicates 의 keep 인자 확인

# %%
t = df.drop_duplicates('item_name')

# %%
t.size
# Out:
# 300

# %%
Ans = df.loc[(df.item_name == 'Steak Salad') | (df.item_name == 'Bowl')]
Ans = Ans.drop_duplicates('item_name')

# %%
Ans
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price  new_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20   22.203125
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99    8.992188

# %% [markdown]
# ### Question 34
# **df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 데이터 프레임화 한 후, item_name를 기준으로 중복행이 있으면 제거하되 마지막 케이스만 남겨라**

# %%
Ans = df.loc[(df.item_name == 'Steak Salad') | (df.item_name == 'Bowl')]
Ans = Ans.drop_duplicates('item_name', keep='last')

# %%
Ans
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price  new_price
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40    7.398438
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69    8.687500

# %% [markdown]
# ### Question 35
# **df의 데이터 중 new_price값이 new_price값의 평균값 이상을 가지는 데이터들을 인덱싱하라**

# %%
df.new_price >= df.new_price.mean()

# %%
Ans = df.loc[df.new_price >= df.new_price.mean()]

# %%
Ans.head(5)
# Out:
#    order_id  quantity         item_name  \
# 4         2         2      Chicken Bowl
# 5         3         1      Chicken Bowl
# 7         4         1     Steak Burrito
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price  new_price
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.984375
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98   10.976562
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75   11.750000
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25    9.250000
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25    9.250000

# %% [markdown]
# ### Question 36
# **df의 데이터 중 item_name의 값이 Izze 데이터를 Fizzy Lizzy로 수정하라**

# %%
df.loc[df.item_name == 'Izze', 'item_name'] = 'Fizzy Lizzy'
Ans = df

# %%
Ans.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                   Fizzy Lizzy       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price  new_price
# 0     $2.39    2.390625
# 1     $3.39    3.390625
# 2     $3.39    3.390625

# %%
# df의 데이터 중 new_price 가격이 평균보다 큰 item_name 이름을 King으로 수정하라

df.loc[df.new_price >= df.new_price.mean(), 'item_name'] = 'King'

# %%
df.loc[df.new_price >= df.new_price.mean()]
# Out:
#       order_id  quantity item_name  \
# 4            2         2      King
# 5            3         1      King
# 7            4         1      King
# 8            4         1      King
# 9            5         1      King
# ...        ...       ...       ...
# 4617      1833         1      King
# 4618      1833         1      King
# 4619      1834         1      King
# 4620      1834         1      King
# 4621      1834         1      King
#
#                                      choice_description item_price  new_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.984375
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98   10.976562
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75   11.750000
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25    9.250000
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25    9.250000
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75   11.750000
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75   11.750000
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25   11.250000
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75    8.750000
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75    8.750000
#
#      choice_descripiton
# 4                   NaN
# 5                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# ...                 ...
# 4617                NaN
# 4618                NaN
# 4619                NaN
# 4620                NaN
# 4621                NaN
#
# [2890 rows x 7 columns]

# %% [markdown]
# ### Question 37
# **df의 데이터 중 choice_description 값이 NaN 인 데이터의 갯수를 구하여라**

# %%
df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# new_price                0
# choice_descripiton    3376
# dtype: int64

# %%
df.loc[ df.choice_description.isna() ]
# Out:
#       order_id  quantity item_name choice_description item_price  new_price
# 0            1         1      King                NaN     $2.39    2.390625
# 3            1         1      King                NaN     $2.39    2.390625
# 6            3         1      King                NaN     $1.69    1.690430
# 10           5         1      King                NaN     $4.45    4.449219
# 14           7         1      King                NaN     $4.45    4.449219
# ...        ...       ...       ...                ...        ...        ...
# 4600      1827         1      King                NaN     $4.45    4.449219
# 4605      1828         1      King                NaN     $4.45    4.449219
# 4613      1831         1      King                NaN     $2.15    2.150391
# 4614      1831         1      King                NaN     $1.50    1.500000
# 4616      1832         1      King                NaN     $4.45    4.449219
#
# [1246 rows x 6 columns]

# %%
df.loc[ df.choice_description.isna() ]['item_name'].value_counts()
# Out:
# King    1246
# Name: item_name, dtype: int64

# %%
Ans = df.choice_description.isnull().sum()

# %%
Ans
# Out:
# 1246

# %% [markdown]
# ### Question 38
# **df의 데이터 중 choice_description 값이 NaN 인 데이터를 NoData 값으로 대체하라(loc 이용)**

# %%
df.loc[df.choice_description.isnull(), 'choice_description'] = 'NoData'
Ans = df

# %%
Ans.head()
# Out:
#    order_id  quantity item_name  \
# 0         1         1      King
# 1         1         1      King
# 2         1         1      King
# 3         1         1      King
# 4         2         2      King
#
#                                   choice_description item_price  new_price  \
# 0                                             NoData     $2.39    2.390625
# 1                                       [Clementine]     $3.39    3.390625
# 2                                            [Apple]     $3.39    3.390625
# 3                                             NoData     $2.39    2.390625
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.984375
#
#   choice_descripiton
# 0             NoData
# 1                NaN
# 2                NaN
# 3             NoData
# 4                NaN

# %% [markdown]
# ### Question 39
# **df의 데이터 중 choice_description 값에 Black이 들어가는 경우를 인덱싱하라**

# %%
df
# Out:
#       order_id  quantity item_name  \
# 0            1         1      King
# 1            1         1      King
# 2            1         1      King
# 3            1         1      King
# 4            2         2      King
# ...        ...       ...       ...
# 4617      1833         1      King
# 4618      1833         1      King
# 4619      1834         1      King
# 4620      1834         1      King
# 4621      1834         1      King
#
#                                      choice_description item_price  new_price  \
# 0                                                   NaN     $2.39    2.390625
# 1                                          [Clementine]     $3.39    3.390625
# 2                                               [Apple]     $3.39    3.390625
# 3                                                   NaN     $2.39    2.390625
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.984375
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75   11.750000
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75   11.750000
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25   11.250000
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75    8.750000
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75    8.750000
#
#      choice_descripiton
# 0                NoData
# 1                   NaN
# 2                   NaN
# 3                NoData
# 4                   NaN
# ...                 ...
# 4617                NaN
# 4618                NaN
# 4619                NaN
# 4620                NaN
# 4621                NaN
#
# [4622 rows x 7 columns]

# %%
Ans = df[df.choice_description.str.contains('Black')]

# %%
Ans.head(5)
# Out:
#     order_id  quantity item_name  \
# 4          2         2      King
# 7          4         1      King
# 9          5         1      King
# 11         6         1      King
# 12         6         1      King
#
#                                    choice_description item_price  new_price  \
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98   16.984375
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75   11.750000
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25    9.250000
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75    8.750000
# 12  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75    8.750000
#
#    choice_descripiton
# 4                 NaN
# 7                 NaN
# 9                 NaN
# 11                NaN
# 12                NaN

# %% [markdown]
# ### Question 40
# **df의 데이터 중 choice_description 값에 Vegetables 들어가지 않는 경우의 갯수를 출력하라**

# %%
Ans = df.loc[df.choice_description.str.contains('Vegetables')]

# %%
Ans
# Out:
#       order_id  quantity item_name  \
# 7            4         1      King
# 11           6         1      King
# 13           7         1      King
# 19          10         1      King
# 39          19         1      King
# ...        ...       ...       ...
# 4611      1830         1      King
# 4612      1831         1      King
# 4619      1834         1      King
# 4620      1834         1      King
# 4621      1834         1      King
#
#                                      choice_description item_price  new_price  \
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75        8.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75        8.75
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75       11.75
# ...                                                 ...        ...        ...
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.25       11.25
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25        9.25
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
#      choice_descripiton
# 7                   NaN
# 11                  NaN
# 13                  NaN
# 19                  NaN
# 39                  NaN
# ...                 ...
# 4611                NaN
# 4612                NaN
# 4619                NaN
# 4620                NaN
# 4621                NaN
#
# [722 rows x 7 columns]

# %% [markdown]
# ### Question 41
# **df의 데이터 중 item_name 값이 N으로 시작하는 데이터를 모두 추출하라**

# %%
Ans.head(3)
# Out:
#      order_id  quantity         item_name         choice_description  \
# 2           1         1  Nantucket Nectar                    [Apple]
# 22         11         1  Nantucket Nectar       [Pomegranate Cherry]
# 105        46         1  Nantucket Nectar  [Pineapple Orange Banana]
#
#     item_price  new_price
# 2       $3.39        3.39
# 22      $3.39        3.39
# 105     $3.39        3.39

# %% [markdown]
# ### Question 42
# **df의 데이터 중 item_name 값의 단어갯수가 15개 이상인 데이터를 인덱싱하라**

# %%
df.item_name.str

# %%
Ans = df[df.item_name.str.len() >= 15]

# %%
Ans.head(3)
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price, new_price, choice_descripiton]
# Index: []

# %% [markdown]
# ### Question 43
# **df의 데이터 중 new_price값이 lst에 해당하는 경우의 데이터 프레임을 구하고 그 갯수를 출력하라**
#
# ```lst =[1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]```

# %%
lst =[1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]

Ans = df.loc[df.new_price.isin(lst)]

# %%
df[df.new_price.values in lst]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [148], line 1
# ----> 1 df[df.new_price.values in lst]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
Ans.head(3)
print(len(Ans))
# Out:
# 682

# %% [markdown]
# >

# %% [markdown]
# >
